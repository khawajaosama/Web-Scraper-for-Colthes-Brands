# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
page=0
data={'product name':[],'image url':[],'product category':[],'price':[]}

# %%
while(True):
    page += 1
    response =  requests.get(f'https://www.gulahmedshop.com/mens-clothes?p={page}')
    soup = BeautifulSoup(response.text,'html.parser')

    for product in soup.find_all('a', {'class':'product-item-link'}):
        
        if product.text.strip():
            
            data['product name'].append(product.text.strip())
            response2=requests.get(product.get('href'))
            
            soup2= BeautifulSoup(response2.text,'html.parser')
            
            img=soup2.find_all('img',{'itemprop':'image'})
            data['image url'].append(img[0].get('src')) if img else data['image url'].append(None)
            
            category = soup2.find_all('div',{'itemprop':'sku'})
            data['product category'].append(category[0].text) if category else data['product category'].append(None)
            
            price = soup2.find_all('span',{'class':'price'})
            data['price'].append(price[0].text) if price else data['price'].append(None)
            
    print(str(page)+' Done')
    print(len(data['product name']),len(data['image url']),len(data['product category']))
    
    if not soup.find_all('a', {'class':'action next'}):
        break
    
data = pd.DataFrame.from_dict(data)
# Out:
# 1 Done
# 45 45 45
# 2 Done
# 90 90 90
# 3 Done
# 135 135 135
# 4 Done
# 180 180 180
# 5 Done
# 225 225 225
# 6 Done
# 270 270 270
# 7 Done
# 315 315 315
# 8 Done
# 360 360 360
# 9 Done
# 405 405 405
# 10 Done
# 450 450 450
# 11 Done
# 495 495 495
# 12 Done
# 540 540 540

# %%
pd.DataFrame.from_dict(data)
# Out:
#                                           product name  \
# 0                      Red Hit-ex Cool JA Shirt RCG-02
# 1                    Multi Casual Shirt CM-YD-2452  CS
# 2              Multi Check Casual Shirt CM-YD-2468  CS
# 3                           Light Beige MEGA SUPER O/S
# 4                        Dark Cream KARANDI (SILK)-MMU
# 5                               Black Opus (Mocado)-GS
# 6                                Skin VISION (ARZOO)-G
# 7                          Mehndi Exclusive Wovn(FD#08
# 8                 Multi Causal Shirt Stripe CM-YD-2682
# 9            Denim Blue Causal Shirt Stripe CM-YD-2680
# 10       Black & White Casual Shirt Checked CM-YD-2664
# 11           Multi Red Casual Shirt Checked CM-YD-2663
# 12                Indigo Causal Shirt Satin CM-YD-2659
# 13        Blue & White Casual Shirt Checked CM-YD-2651
# 14   Navy Grey Checked Causal Shirt Yarn Dyed CM-YD...
# 15        Off White Basic Henley Tee HS-HEN-SIG-D05-01
# 16                      White Fashion Tee JGP-URB-D172
# 17                       Navy Fashion Tee JGP-URB-D170
# 18                      White Fashion Tee JGP-URB-D169
# 19                        Beige Basic Tee JVN-SIG-D021
# 20                   Smoke Grey Basic Tee JVN-SIG-D019
# 21              Dark Green Fashion Polo PKP-URB-D46-04
# 22              Burgundy Fashion Tee YD-URB-TEE-D04-03
# 23                       Grey Fashion Tee JGP-URB-D138
# 24                      Mustard Fashion Polo PKP-ST-47
# 25                      White Fashion Tee JGP-URB-D133
# 26                         Navy Basic Tee JCN-SIG-D019
# 27     Dark Grey Causal Shirt Yarn Dyed CM-YD-2482  CS
# 28                                    Purple GUL KORUS
# 29                                           GUL KORUS
# ..                                                 ...
https://d224nth7ac0evy.cloudfront.net/catalog/...
# 538  https://d224nth7ac0evy.cloudfront.net/catalog/...
# 539  https://d224nth7ac0evy.cloudfront.net/catalog/...
#
#             product category      price
# 0    MEN-FABRIC-RS-19-194027  PKR 1,024
# 1          M-AP-18-178372 -P  PKR 1,617
# 2          M-AP-18-178767 -P  PKR 1,497
# 3          Men-Fabric-100817  PKR 1,355
# 4          Men-Fabric-176396  PKR 2,744
# 5          Men-Fabric-173968  PKR 1,827
# 6          Men-Fabric-199928  PKR 1,607
# 7          Men-Fabric-191852  PKR 2,489
# 8          M-AP-19-192795 -P  PKR 1,617
# 9          M-AP-19-192785 -P  PKR 1,617
# 10         M-AP-19-191656 -P  PKR 1,797
# 11         M-AP-19-191651 -P  PKR 1,797
# 12         M-AP-19-191631 -P  PKR 1,797
# 13         M-AP-19-191591 -P  PKR 1,797
# 14         M-AP-19-190333 -P  PKR 1,497
# 15         M-AP-19-189621 -P    PKR 717
# 16         M-AP-19-189597 -P    PKR 597
# 17         M-AP-19-189589 -P    PKR 597
# 18         M-AP-19-189585 -P    PKR 597
# 19         M-AP-19-189537 -P    PKR 477
# 20         M-AP-19-189529 -P    PKR 477
# 21         M-AP-19-188032 -P  PKR 1,017
# 22         M-AP-19-187980 -P    PKR 717
# 23         M-AP-19-187916 -P    PKR 597
# 24         M-AP-19-187854 -P    PKR 897
# 25         M-AP-19-187806 -P    PKR 597
# 26         M-AP-19-187770 -P    PKR 477
# 27         M-AP-19-184287 -P  PKR 1,497
# 28         Men-Fabric-101473  PKR 1,859
# 29         Men-Fabric-101468  PKR 1,859
# ..                       ...        ...
# 510     M-MR-BC-18-156299 -P  PKR 1,497
# 511       MS-WC-17-144162 -P  PKR 2,500
# 512       MS-WC-17-144214 -P  PKR 2,500
# 513       MS-WC-17-147017 -P  PKR 2,100
# 514       MS-WC-17-146289 -P  PKR 3,100
# 515       MS-WC-17-144158 -P  PKR 2,500
# 516       MS-WC-17-144146 -P  PKR 2,300
# 517       MS-FM-17-138457 -P  PKR 2,090
# 518       MS-WC-17-124533 -P  PKR 2,473
# 519         MA-W-17-146957-P  PKR 2,900
# 520         MA-W-17-146953-P  PKR 3,500
# 521         MA-W-17-146949-P  PKR 2,900
# 522         MA-W-17-147021-P  PKR 2,100
# 523         MA-W-17-146244-P  PKR 2,900
# 524             M-C-139754-P  PKR 1,061
# 525             M-C-139786-P  PKR 1,061
# 526       GA_BELT_07-Small-P  PKR 1,275
# 527       GA_BELT_10-Small-P  PKR 1,275
# 528       GA_BELT_12-Small-P  PKR 1,275
# 529     GA_BELT_11-1-Small-P    PKR 975
# 530                  C-LATHA  PKR 2,100
# 531              C-LATHA-BOX  PKR 2,250
# 532            S-17-132018-P  PKR 2,090
# 533            S-17-132025-P  PKR 2,090
# 534            S-17-132032-P  PKR 2,090
# 535            S-17-139742-P  PKR 1,061
# 536            S-17-139762-P  PKR 1,061
# 537            S-17-139766-P  PKR 1,061
# 538        Men-Fabric-141995  PKR 2,100
# 539         Men-Fabric-16299  PKR 2,100
#
# [540 rows x 4 columns]

# %%
data = pd.DataFrame.from_dict(data)
data.to_csv('gul_ahmed_data.csv')
